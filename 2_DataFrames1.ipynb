# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %% [markdown]
# ## Shared methods and attributes between series and data frames
# A method() is just a command to an object. Different objects can still respond to the same command. Some objects have exclusive methods.

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape  # (rows, columns)
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# Combine the axes that make up data frame
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %% [markdown]
# ## Exclusive attributes for Data Frames (only)

# %%
nba.info()  # dtypes: float64(4), object(5) -- 4 and 5 columns: get_dtype_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ## Differences between shared methods (series vs. data frames)

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1, 2, 3])
s.sum()
# Out:
# 6

# %%
rev.sum()  # Results in brand new series
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
# Sum vertically is available to both series and DFs. 
# However, horizontal sums is only available to DFs.
# How to do .sum() by date? Use axis parameter.
rev.sum(axis = "columns")  # or rev.sum(axis = 1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis = 0) # Or, rev.sum(axis = "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %% [markdown]
# ## Select ONE column from a DataFrame

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Name  #The returns a SERIES bc of extracting one column from a DF
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
#                 ...
# 428            Al-Farouq Aminu
# 429            Pat Connaughton
# 430               Allen Crabbe
# 431                   Ed Davis
# 432           Maurice Harkless
# 433           Gerald Henderson
# 434                Chris Kaman
# 435             Meyers Leonard
# 436             Damian Lillard
# 437              C.J. McCollum
# 438               Luis Montero
# 439              Mason Plumlee
# 440              Brian Roberts
# 441                Noah Vonleh
# 442              Trevor Booker
# 443                 Trey Burke
# 444                 Alec Burks
# 445                 Dante Exum
# 446             Derrick Favors
# 447                Rudy Gobert
# 448             Gordon Hayward
# 449                Rodney Hood
# 450                 Joe Ingles
# 451              Chris Johnson
# 452                 Trey Lyles
# 453               Shelvin Mack
# 454                  Raul Neto
# 455               Tibor Pleiss
# 456                Jeff Withey
# 457                        NaN
# Name: Name, Length: 458, dtype: object

# %%
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
# 5      90.0
# 6      55.0
# 7      41.0
# 8      12.0
# 9      36.0
# 10      7.0
# 11      4.0
# 12     11.0
# 13     13.0
# 14     44.0
# 15     44.0
# 16     22.0
# 17     21.0
# 18     24.0
# 19      2.0
# 20     10.0
# 21      6.0
# 22      0.0
# 23     11.0
# 24      1.0
# 25     33.0
# 26     41.0
# 27     14.0
# 28     15.0
# 29     30.0
#        ...
# 428     8.0
# 429     5.0
# 430    23.0
# 431    17.0
# 432     4.0
# 433     9.0
# 434    35.0
# 435    11.0
# 436     0.0
# 437     3.0
# 438    44.0
# 439    24.0
# 440     2.0
# 441    21.0
# 442    33.0
# 443     3.0
# 444    10.0
# 445    11.0
# 446    15.0
# 447    27.0
# 448    20.0
# 449     5.0
# 450     2.0
# 451    23.0
# 452    41.0
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba.Salary
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# 447     1175880.0
# 448    15409570.0
# 449     1348440.0
# 450     2050000.0
# 451      981348.0
# 452     2239800.0
# 453     2433333.0
# 454      900000.0
# 455     2900000.0
# 456      947276.0
# 457           NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba.Name
nba.Number
nba.Salary

Output = None  # Tells NB not to print output

# %%
# This is teacher's preferred choice since it handles columns with spaces in between
nba["Name"]
nba["Salary"]
nba["Number"]

Output = None

# %%
type(nba["Name"])  #again, extracting one column from DF results in SERIES
# Out:
# pandas.core.series.Series

# %%
nba["Name"].head(10)  #Can chain methods
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %% [markdown]
# ## Selecting two or more columns from a DataFrame

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[["Name", "Team"]]  # Two or more columns results in new DF
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# 17           Wayne Ellington           Brooklyn Nets
# 18   Rondae Hollis-Jefferson           Brooklyn Nets
# 19              Jarrett Jack           Brooklyn Nets
# 20            Sergey Karasev           Brooklyn Nets
# 21           Sean Kilpatrick           Brooklyn Nets
# 22              Shane Larkin           Brooklyn Nets
# 23               Brook Lopez           Brooklyn Nets
# 24          Chris McCullough           Brooklyn Nets
# 25               Willie Reed           Brooklyn Nets
# 26           Thomas Robinson           Brooklyn Nets
# 27                Henry Sims           Brooklyn Nets
# 28              Donald Sloan           Brooklyn Nets
# 29            Thaddeus Young           Brooklyn Nets
# ..                       ...                     ...
# 428          Al-Farouq Aminu  Portland Trail Blazers
# 429          Pat Connaughton  Portland Trail Blazers
# 430             Allen Crabbe  Portland Trail Blazers
# 431                 Ed Davis  Portland Trail Blazers
# 432         Maurice Harkless  Portland Trail Blazers
# 433         Gerald Henderson  Portland Trail Blazers
# 434              Chris Kaman  Portland Trail Blazers
# 435           Meyers Leonard  Portland Trail Blazers
# 436           Damian Lillard  Portland Trail Blazers
# 437            C.J. McCollum  Portland Trail Blazers
# 438             Luis Montero  Portland Trail Blazers
# 439            Mason Plumlee  Portland Trail Blazers
# 440            Brian Roberts  Portland Trail Blazers
# 441              Noah Vonleh  Portland Trail Blazers
# 442            Trevor Booker               Utah Jazz
# 443               Trey Burke               Utah Jazz
# 444               Alec Burks               Utah Jazz
# 445               Dante Exum               Utah Jazz
# 446           Derrick Favors               Utah Jazz
# 447              Rudy Gobert               Utah Jazz
# 448           Gordon Hayward               Utah Jazz
# 449              Rodney Hood               Utah Jazz
# 450               Joe Ingles               Utah Jazz
# 451            Chris Johnson               Utah Jazz
# 452               Trey Lyles               Utah Jazz
# 453             Shelvin Mack               Utah Jazz
# 454                Raul Neto               Utah Jazz
# 455             Tibor Pleiss               Utah Jazz
# 456              Jeff Withey               Utah Jazz
# 457                      NaN                     NaN
#
# [458 rows x 2 columns]

# %%
# Want to change the column order?
nba[["Team", "Name"]].head()
nba[["Number", "College", "Salary"]].tail(10)
# Out:
#      Number   College      Salary
# 448    20.0    Butler  15409570.0
# 449     5.0      Duke   1348440.0
# 450     2.0       NaN   2050000.0
# 451    23.0    Dayton    981348.0
# 452    41.0  Kentucky   2239800.0
# 453     8.0    Butler   2433333.0
# 454    25.0       NaN    900000.0
# 455    21.0       NaN   2900000.0
# 456    24.0    Kansas    947276.0
# 457     NaN       NaN         NaN

# %%
# Another elegant way to extract multiple columns when
# working with data that has several columns
select = ['Salary', 'Team', 'Name']
nba[select]
# Out:
#          Salary                    Team                     Name
# 0     7730337.0          Boston Celtics            Avery Bradley
# 1     6796117.0          Boston Celtics              Jae Crowder
# 2           NaN          Boston Celtics             John Holland
# 3     1148640.0          Boston Celtics              R.J. Hunter
# 4     5000000.0          Boston Celtics            Jonas Jerebko
# 5    12000000.0          Boston Celtics             Amir Johnson
# 6     1170960.0          Boston Celtics            Jordan Mickey
# 7     2165160.0          Boston Celtics             Kelly Olynyk
# 8     1824360.0          Boston Celtics             Terry Rozier
# 9     3431040.0          Boston Celtics             Marcus Smart
# 10    2569260.0          Boston Celtics          Jared Sullinger
# 11    6912869.0          Boston Celtics            Isaiah Thomas
# 12    3425510.0          Boston Celtics              Evan Turner
# 13    1749840.0          Boston Celtics              James Young
# 14    2616975.0          Boston Celtics             Tyler Zeller
# 15    3425510.0           Brooklyn Nets         Bojan Bogdanovic
# 16     845059.0           Brooklyn Nets             Markel Brown
# 17    1500000.0           Brooklyn Nets          Wayne Ellington
# 18    1335480.0           Brooklyn Nets  Rondae Hollis-Jefferson
# 19    6300000.0           Brooklyn Nets             Jarrett Jack
# 20    1599840.0           Brooklyn Nets           Sergey Karasev
# 21     134215.0           Brooklyn Nets          Sean Kilpatrick
# 22    1500000.0           Brooklyn Nets             Shane Larkin
# 23   19689000.0           Brooklyn Nets              Brook Lopez
# 24    1140240.0           Brooklyn Nets         Chris McCullough
# 25     947276.0           Brooklyn Nets              Willie Reed
# 26     981348.0           Brooklyn Nets          Thomas Robinson
# 27     947276.0           Brooklyn Nets               Henry Sims
# 28     947276.0           Brooklyn Nets             Donald Sloan
# 29   11235955.0           Brooklyn Nets           Thaddeus Young
# ..          ...                     ...                      ...
# 428   8042895.0  Portland Trail Blazers          Al-Farouq Aminu
# 429    625093.0  Portland Trail Blazers          Pat Connaughton
# 430    947276.0  Portland Trail Blazers             Allen Crabbe
# 431   6980802.0  Portland Trail Blazers                 Ed Davis
# 432   2894059.0  Portland Trail Blazers         Maurice Harkless
# 433   6000000.0  Portland Trail Blazers         Gerald Henderson
# 434   5016000.0  Portland Trail Blazers              Chris Kaman
# 435   3075880.0  Portland Trail Blazers           Meyers Leonard
# 436   4236287.0  Portland Trail Blazers           Damian Lillard
# 437   2525160.0  Portland Trail Blazers            C.J. McCollum
# 438    525093.0  Portland Trail Blazers             Luis Montero
# 439   1415520.0  Portland Trail Blazers            Mason Plumlee
# 440   2854940.0  Portland Trail Blazers            Brian Roberts
# 441   2637720.0  Portland Trail Blazers              Noah Vonleh
# 442   4775000.0               Utah Jazz            Trevor Booker
# 443   2658240.0               Utah Jazz               Trey Burke
# 444   9463484.0               Utah Jazz               Alec Burks
# 445   3777720.0               Utah Jazz               Dante Exum
# 446  12000000.0               Utah Jazz           Derrick Favors
# 447   1175880.0               Utah Jazz              Rudy Gobert
# 448  15409570.0               Utah Jazz           Gordon Hayward
# 449   1348440.0               Utah Jazz              Rodney Hood
# 450   2050000.0               Utah Jazz               Joe Ingles
# 451    981348.0               Utah Jazz            Chris Johnson
# 452   2239800.0               Utah Jazz               Trey Lyles
# 453   2433333.0               Utah Jazz             Shelvin Mack
# 454    900000.0               Utah Jazz                Raul Neto
# 455   2900000.0               Utah Jazz             Tibor Pleiss
# 456    947276.0               Utah Jazz              Jeff Withey
# 457         NaN                     NaN                      NaN
#
# [458 rows x 3 columns]

# %% [markdown]
# ## Adding new columns to DataFrame

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Sport"]  # Results in error because column doeesn't exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sport'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-bdc29365dd40> in <module>()
# ----> 1 nba["Sport"]  # Results in error because column doeesn't exist
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sport'

# %%
# Scalar value: Every value in new column will equal "Basketball"
nba["Sport"] = "Basketball"

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba.shape
# Out:
# (458, 10)

# %%
nba["League"] = "National Basketball Association"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association
# 3      Georgia State  1148640.0  Basketball  National Basketball Association
# 4                NaN  5000000.0  Basketball  National Basketball Association

# %%
# Returning to original DF
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(3, column = "Sport", value = "Basketball", allow_duplicates = True)
nba
# Out:
#                         Name                    Team  Number       Sport  \
# 0              Avery Bradley          Boston Celtics     0.0  Basketball
# 1                Jae Crowder          Boston Celtics    99.0  Basketball
# 2               John Holland          Boston Celtics    30.0  Basketball
# 3                R.J. Hunter          Boston Celtics    28.0  Basketball
# 4              Jonas Jerebko          Boston Celtics     8.0  Basketball
# 5               Amir Johnson          Boston Celtics    90.0  Basketball
# 6              Jordan Mickey          Boston Celtics    55.0  Basketball
# 7               Kelly Olynyk          Boston Celtics    41.0  Basketball
# 8               Terry Rozier          Boston Celtics    12.0  Basketball
# 9               Marcus Smart          Boston Celtics    36.0  Basketball
# 10           Jared Sullinger          Boston Celtics     7.0  Basketball
# 11             Isaiah Thomas          Boston Celtics     4.0  Basketball
# 12               Evan Turner          Boston Celtics    11.0  Basketball
# 13               James Young          Boston Celtics    13.0  Basketball
# 14              Tyler Zeller          Boston Celtics    44.0  Basketball
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0  Basketball
# 16              Markel Brown           Brooklyn Nets    22.0  Basketball
# 17           Wayne Ellington           Brooklyn Nets    21.0  Basketball
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0  Basketball
# 19              Jarrett Jack           Brooklyn Nets     2.0  Basketball
# 20            Sergey Karasev           Brooklyn Nets    10.0  Basketball
# 21           Sean Kilpatrick           Brooklyn Nets     6.0  Basketball
# 22              Shane Larkin           Brooklyn Nets     0.0  Basketball
# 23               Brook Lopez           Brooklyn Nets    11.0  Basketball
# 24          Chris McCullough           Brooklyn Nets     1.0  Basketball
# 25               Willie Reed           Brooklyn Nets    33.0  Basketball
# 26           Thomas Robinson           Brooklyn Nets    41.0  Basketball
# 27                Henry Sims           Brooklyn Nets    14.0  Basketball
# 28              Donald Sloan           Brooklyn Nets    15.0  Basketball
# 29            Thaddeus Young           Brooklyn Nets    30.0  Basketball
# ..                       ...                     ...     ...         ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0  Basketball
# 429          Pat Connaughton  Portland Trail Blazers     5.0  Basketball
# 430             Allen Crabbe  Portland Trail Blazers    23.0  Basketball
# 431                 Ed Davis  Portland Trail Blazers    17.0  Basketball
# 432         Maurice Harkless  Portland Trail Blazers     4.0  Basketball
# 433         Gerald Henderson  Portland Trail Blazers     9.0  Basketball
# 434              Chris Kaman  Portland Trail Blazers    35.0  Basketball
# 435           Meyers Leonard  Portland Trail Blazers    11.0  Basketball
# 436           Damian Lillard  Portland Trail Blazers     0.0  Basketball
# 437            C.J. McCollum  Portland Trail Blazers     3.0  Basketball
# 438             Luis Montero  Portland Trail Blazers    44.0  Basketball
# 439            Mason Plumlee  Portland Trail Blazers    24.0  Basketball
# 440            Brian Roberts  Portland Trail Blazers     2.0  Basketball
# 441              Noah Vonleh  Portland Trail Blazers    21.0  Basketball
# 442            Trevor Booker               Utah Jazz    33.0  Basketball
# 443               Trey Burke               Utah Jazz     3.0  Basketball
# 444               Alec Burks               Utah Jazz    10.0  Basketball
# 445               Dante Exum               Utah Jazz    11.0  Basketball
# 446           Derrick Favors               Utah Jazz    15.0  Basketball
# 447              Rudy Gobert               Utah Jazz    27.0  Basketball
# 448           Gordon Hayward               Utah Jazz    20.0  Basketball
# 449              Rodney Hood               Utah Jazz     5.0  Basketball
# 450               Joe Ingles               Utah Jazz     2.0  Basketball
# 451            Chris Johnson               Utah Jazz    23.0  Basketball
# 452               Trey Lyles               Utah Jazz    41.0  Basketball
# 453             Shelvin Mack               Utah Jazz     8.0  Basketball
# 454                Raul Neto               Utah Jazz    25.0  Basketball
# 455             Tibor Pleiss               Utah Jazz    21.0  Basketball
# 456              Jeff Withey               Utah Jazz    24.0  Basketball
# 457                      NaN                     NaN     NaN  Basketball
#
#           Sport Position   Age Height  Weight            College      Salary
# 0    Basketball       PG  25.0    6-2   180.0              Texas   7730337.0
# 1    Basketball       SF  25.0    6-6   235.0          Marquette   6796117.0
# 2    Basketball       SG  27.0    6-5   205.0  Boston University         NaN
# 3    Basketball       SG  22.0    6-5   185.0      Georgia State   1148640.0
# 4    Basketball       PF  29.0   6-10   231.0                NaN   5000000.0
# 5    Basketball       PF  29.0    6-9   240.0                NaN  12000000.0
# 6    Basketball       PF  21.0    6-8   235.0                LSU   1170960.0
# 7    Basketball        C  25.0    7-0   238.0            Gonzaga   2165160.0
# 8    Basketball       PG  22.0    6-2   190.0         Louisville   1824360.0
# 9    Basketball       PG  22.0    6-4   220.0     Oklahoma State   3431040.0
# 10   Basketball        C  24.0    6-9   260.0         Ohio State   2569260.0
# 11   Basketball       PG  27.0    5-9   185.0         Washington   6912869.0
# 12   Basketball       SG  27.0    6-7   220.0         Ohio State   3425510.0
# 13   Basketball       SG  20.0    6-6   215.0           Kentucky   1749840.0
# 14   Basketball        C  26.0    7-0   253.0     North Carolina   2616975.0
# 15   Basketball       SG  27.0    6-8   216.0                NaN   3425510.0
# 16   Basketball       SG  24.0    6-3   190.0     Oklahoma State    845059.0
# 17   Basketball       SG  28.0    6-4   200.0     North Carolina   1500000.0
# 18   Basketball       SG  21.0    6-7   220.0            Arizona   1335480.0
# 19   Basketball       PG  32.0    6-3   200.0       Georgia Tech   6300000.0
# 20   Basketball       SG  22.0    6-7   208.0                NaN   1599840.0
# 21   Basketball       SG  26.0    6-4   219.0         Cincinnati    134215.0
# 22   Basketball       PG  23.0   5-11   175.0         Miami (FL)   1500000.0
# 23   Basketball        C  28.0    7-0   275.0           Stanford  19689000.0
# 24   Basketball       PF  21.0   6-11   200.0           Syracuse   1140240.0
# 25   Basketball       PF  26.0   6-10   220.0        Saint Louis    947276.0
# 26   Basketball       PF  25.0   6-10   237.0             Kansas    981348.0
# 27   Basketball        C  26.0   6-10   248.0         Georgetown    947276.0
# 28   Basketball       PG  28.0    6-3   205.0          Texas A&M    947276.0
# 29   Basketball       PF  27.0    6-8   221.0       Georgia Tech  11235955.0
# ..          ...      ...   ...    ...     ...                ...         ...
# 428  Basketball       SF  25.0    6-9   215.0        Wake Forest   8042895.0
# 429  Basketball       SG  23.0    6-5   206.0         Notre Dame    625093.0
# 430  Basketball       SG  24.0    6-6   210.0         California    947276.0
# 431  Basketball        C  27.0   6-10   240.0     North Carolina   6980802.0
# 432  Basketball       SF  23.0    6-9   215.0         St. John's   2894059.0
# 433  Basketball       SG  28.0    6-5   215.0               Duke   6000000.0
# 434  Basketball        C  34.0    7-0   265.0   Central Michigan   5016000.0
# 435  Basketball       PF  24.0    7-1   245.0           Illinois   3075880.0
# 436  Basketball       PG  25.0    6-3   195.0        Weber State   4236287.0
# 437  Basketball       SG  24.0    6-4   200.0             Lehigh   2525160.0
# 438  Basketball       SG  23.0    6-7   185.0     Westchester CC    525093.0
# 439  Basketball        C  26.0   6-11   235.0               Duke   1415520.0
# 440  Basketball       PG  30.0    6-1   173.0             Dayton   2854940.0
# 441  Basketball       PF  20.0    6-9   240.0            Indiana   2637720.0
# 442  Basketball       PF  28.0    6-8   228.0            Clemson   4775000.0
# 443  Basketball       PG  23.0    6-1   191.0           Michigan   2658240.0
# 444  Basketball       SG  24.0    6-6   214.0           Colorado   9463484.0
# 445  Basketball       PG  20.0    6-6   190.0                NaN   3777720.0
# 446  Basketball       PF  24.0   6-10   265.0       Georgia Tech  12000000.0
# 447  Basketball        C  23.0    7-1   245.0                NaN   1175880.0
# 448  Basketball       SF  26.0    6-8   226.0             Butler  15409570.0
# 449  Basketball       SG  23.0    6-8   206.0               Duke   1348440.0
# 450  Basketball       SF  28.0    6-8   226.0                NaN   2050000.0
# 451  Basketball       SF  26.0    6-6   206.0             Dayton    981348.0
# 452  Basketball       PF  20.0   6-10   234.0           Kentucky   2239800.0
# 453  Basketball       PG  26.0    6-3   203.0             Butler   2433333.0
# 454  Basketball       PG  24.0    6-1   179.0                NaN    900000.0
# 455  Basketball        C  26.0    7-3   256.0                NaN   2900000.0
# 456  Basketball        C  26.0    7-0   231.0             Kansas    947276.0
# 457  Basketball      NaN   NaN    NaN     NaN                NaN         NaN
#
# [458 rows x 11 columns]

# %%
nba.insert(7, column = "League", value = "NBA", allow_duplicates = True)
nba.head()
# Out:
#             Name            Team  Number       Sport       Sport Position  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball  Basketball       PG
# 1    Jae Crowder  Boston Celtics    99.0  Basketball  Basketball       SF
# 2   John Holland  Boston Celtics    30.0  Basketball  Basketball       SG
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball  Basketball       SG
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball  Basketball       PF
#
#     Age League League Height  Weight            College     Salary
# 0  25.0    NBA    NBA    6-2   180.0              Texas  7730337.0
# 1  25.0    NBA    NBA    6-6   235.0          Marquette  6796117.0
# 2  27.0    NBA    NBA    6-5   205.0  Boston University        NaN
# 3  22.0    NBA    NBA    6-5   185.0      Georgia State  1148640.0
# 4  29.0    NBA    NBA   6-10   231.0                NaN  5000000.0

# %%
nba.insert(3, column = "Dinner", value = "Fajitas")

# %%
nba.head()
# Out:
#             Name            Team  Number   Dinner       Sport       Sport  \
# 0  Avery Bradley  Boston Celtics     0.0  Fajitas  Basketball  Basketball
# 1    Jae Crowder  Boston Celtics    99.0  Fajitas  Basketball  Basketball
# 2   John Holland  Boston Celtics    30.0  Fajitas  Basketball  Basketball
# 3    R.J. Hunter  Boston Celtics    28.0  Fajitas  Basketball  Basketball
# 4  Jonas Jerebko  Boston Celtics     8.0  Fajitas  Basketball  Basketball
#
#   Position   Age League League Height  Weight            College     Salary
# 0       PG  25.0    NBA    NBA    6-2   180.0              Texas  7730337.0
# 1       SF  25.0    NBA    NBA    6-6   235.0          Marquette  6796117.0
# 2       SG  27.0    NBA    NBA    6-5   205.0  Boston University        NaN
# 3       SG  22.0    NBA    NBA    6-5   185.0      Georgia State  1148640.0
# 4       PF  29.0    NBA    NBA   6-10   231.0                NaN  5000000.0

# %% [markdown]
# ## Broadasting Operations
# Some methods (.sort_values()) apply to entire series. Others (.apply()) only apply to each value in a series. Like a broadcasting tower. The command operates on the values of the series, rather than acting on the series as a whole.

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ### Examples of methods that apply one by one
# **Cool stuff!** .add(), .sub(), .mul(), .div(), +, -, *

# %%
nba["Age"].add(5)  # Even works with NaN values
nba["Age"] + 5  # same as above 

nba["Salary"].sub(5000000)
nba["Salary"] - 5000000

nba["Weight"].mul(0.453592)
nba["Weight in Kilograms"] = nba["Weight"] * .453592

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms
# 0              Texas  7730337.0            81.646560
# 1          Marquette  6796117.0           106.594120
# 2  Boston University        NaN            92.986360
# 3      Georgia State  1148640.0            83.914520
# 4                NaN  5000000.0           104.779752

# %%
nba["Salary"].div(1000000)
nba["Salary in Millions"] = nba["Salary"] / 1000000

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0            81.646560            7.730337
# 1          Marquette  6796117.0           106.594120            6.796117
# 2  Boston University        NaN            92.986360                 NaN
# 3      Georgia State  1148640.0            83.914520            1.148640
# 4                NaN  5000000.0           104.779752            5.000000

# %% [markdown]
# ## A review of the .value_counts() method
# Only can be used on SERIES. Great way to get a unique count on a single column (or series)

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Team"].value_counts()
nba["Position"].value_counts().head(1)  # The most popular position in dataset
nba["Weight"].value_counts().tail(1)
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 1100602.0      5
# 16407500.0     5
# 5000000.0      5
# 12000000.0     5
# 8000000.0      5
# 4000000.0      5
# 3000000.0      4
# 7000000.0      4
# 2814000.0      4
# 1000000.0      4
# 19689000.0     4
# 200600.0       3
# 8500000.0      3
# 2500000.0      3
# 1015421.0      3
# 2854940.0      3
# 13500000.0     3
# 5543725.0      3
# 2288205.0      2
# 1270964.0      2
# 2900000.0      2
# 1007026.0      2
# 111444.0       2
# 13000000.0     2
# 1500000.0      2
# 1842000.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# 5016000.0      1
# 3333333.0      1
# 1824360.0      1
# 8042895.0      1
# 1242720.0      1
# 2489530.0      1
# 5103120.0      1
# 9463484.0      1
# 700902.0       1
# Name: Salary, Length: 309, dtype: int64

# %%
nba["Name"][1]
# Out:
# 'Jae Crowder'

# %%
'Jae Crowder' in nba["Name"]
# Out:
# False

# %%
nba["Name"][:10]
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %% [markdown]
# ## Drop rows with null values
# Use the .dropna(how = "all", inplace=, axis=, subset=[])

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
# Only remove a row if ALL values are null .dropna(how = 'all')
# Also has an inplace parameter
nba.dropna(how = "all").head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(how = 'all', inplace = True)

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
# Remove columns that have ANY null values
nba.dropna(axis = 1).head()  # Or axis = "columns"
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0

# %%
# Want to remove from a specific row/column? .dropna(subset = ["Salary"])
# The subset accepts a list of strings.
# Ex. subset=["Salary"] will only drop rows if there's a null value in the Salary column
nba.dropna(subset = ["Salary", "College"]).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %% [markdown]
# ## Fill in Null values with .fillna() Method

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Not best if inconsistent varied data type set
# Best to call it on a SERIES instead
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 445               Dante Exum               Utah Jazz    11.0       PG  20.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 457                        0                       0     0.0        0   0.0
#
#     Height  Weight            College      Salary
# 0      6-2   180.0              Texas   7730337.0
# 1      6-6   235.0          Marquette   6796117.0
# 2      6-5   205.0  Boston University         0.0
# 3      6-5   185.0      Georgia State   1148640.0
# 4     6-10   231.0                  0   5000000.0
# 5      6-9   240.0                  0  12000000.0
# 6      6-8   235.0                LSU   1170960.0
# 7      7-0   238.0            Gonzaga   2165160.0
# 8      6-2   190.0         Louisville   1824360.0
# 9      6-4   220.0     Oklahoma State   3431040.0
# 10     6-9   260.0         Ohio State   2569260.0
# 11     5-9   185.0         Washington   6912869.0
# 12     6-7   220.0         Ohio State   3425510.0
# 13     6-6   215.0           Kentucky   1749840.0
# 14     7-0   253.0     North Carolina   2616975.0
# 15     6-8   216.0                  0   3425510.0
# 16     6-3   190.0     Oklahoma State    845059.0
# 17     6-4   200.0     North Carolina   1500000.0
# 18     6-7   220.0            Arizona   1335480.0
# 19     6-3   200.0       Georgia Tech   6300000.0
# 20     6-7   208.0                  0   1599840.0
# 21     6-4   219.0         Cincinnati    134215.0
# 22    5-11   175.0         Miami (FL)   1500000.0
# 23     7-0   275.0           Stanford  19689000.0
# 24    6-11   200.0           Syracuse   1140240.0
# 25    6-10   220.0        Saint Louis    947276.0
# 26    6-10   237.0             Kansas    981348.0
# 27    6-10   248.0         Georgetown    947276.0
# 28     6-3   205.0          Texas A&M    947276.0
# 29     6-8   221.0       Georgia Tech  11235955.0
# ..     ...     ...                ...         ...
# 428    6-9   215.0        Wake Forest   8042895.0
# 429    6-5   206.0         Notre Dame    625093.0
# 430    6-6   210.0         California    947276.0
# 431   6-10   240.0     North Carolina   6980802.0
# 432    6-9   215.0         St. John's   2894059.0
# 433    6-5   215.0               Duke   6000000.0
# 434    7-0   265.0   Central Michigan   5016000.0
# 435    7-1   245.0           Illinois   3075880.0
# 436    6-3   195.0        Weber State   4236287.0
# 437    6-4   200.0             Lehigh   2525160.0
# 438    6-7   185.0     Westchester CC    525093.0
# 439   6-11   235.0               Duke   1415520.0
# 440    6-1   173.0             Dayton   2854940.0
# 441    6-9   240.0            Indiana   2637720.0
# 442    6-8   228.0            Clemson   4775000.0
# 443    6-1   191.0           Michigan   2658240.0
# 444    6-6   214.0           Colorado   9463484.0
# 445    6-6   190.0                  0   3777720.0
# 446   6-10   265.0       Georgia Tech  12000000.0
# 447    7-1   245.0                  0   1175880.0
# 448    6-8   226.0             Butler  15409570.0
# 449    6-8   206.0               Duke   1348440.0
# 450    6-8   226.0                  0   2050000.0
# 451    6-6   206.0             Dayton    981348.0
# 452   6-10   234.0           Kentucky   2239800.0
# 453    6-3   203.0             Butler   2433333.0
# 454    6-1   179.0                  0    900000.0
# 455    7-3   256.0                  0   2900000.0
# 456    7-0   231.0             Kansas    947276.0
# 457      0     0.0                  0         0.0
#
# [458 rows x 9 columns]

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ## The .astype() Method
# Can convert datatype of a series but can't use if have NULL values.
# Note: .astype() doesn't have inplace so have to reassign instead.

# %%
# Gotta clear NULL values before using .astype()
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4               None  5000000.0

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"] = nba["Salary"].astype(dtype = "int")
nba["Salary"].head()
# Out:
# 0    7730337
# 1    6796117
# 2          0
# 3    1148640
# 4    5000000
# Name: Salary, dtype: int64

# %%
nba["Age"] = nba["Age"].astype(dtype = "int")
nba["Age"].head(3)
# Out:
# 0    25
# 1    25
# 2    27
# Name: Age, dtype: int64

# %%
nba["Number"] = nba["Number"].astype(dtype = "int")
nba["Number"].head()
# Out:
# 0     0
# 1    99
# 2    30
# 3    28
# 4     8
# Name: Number, dtype: int64

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(2), float64(1), int64(3), object(3)
# memory usage: 51.1+ KB

# %% [markdown]
# ** Unique Pandas only (not in Python) dtype: Categories **
# Really ideal when you have a small amount of unique values in a data frame. Ex. Employees with 1 million rows with a Gender column or Month column (limited values - male/female; jan/feb/mar...). Categories are good are reducing the memory of the DF.
#
# ## .nunique() returns countd essentially

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype(dtype = "category")

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba["Team"] = nba["Team"].astype(dtype = "category")
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %% [markdown]
# ## Sort DataFrame with .sort_values method - Part 1

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values("Name", ascending = False)
nba.sort_values("Age", ascending = False)
nba.sort_values("Salary", ascending = False).head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College      Salary
# 109   212.0       NaN  25000000.0
# 169   250.0       NaN  22970500.0
# 33    240.0  Syracuse  22875000.0

# %%
# If you have nulls NaN in data, can use na_position parameter
# to position them at the end or beginning
nba.sort_values("Salary", na_position = "first").head()
# Out:
#               Name                 Team  Number Position   Age Height  Weight  \
# 2     John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# 46     Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9   254.0
# 171  Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6   225.0
# 264  Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2   180.0
# 269   Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3   190.0
#
#                College  Salary
# 2    Boston University     NaN
# 46                Duke     NaN
# 171               Duke     NaN
# 264               UCLA     NaN
# 269            Detroit     NaN

# %%
nba.sort_values("Salary", ascending = False, na_position = "first").tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %% [markdown]
# ## Sort a DataFrame with MULTIPLE COLUMNS using .sort_values() - Part 2
# The OPTIMAL data type to use in Pandas when you want to specify more than one thing is the Python LIST

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)

# %%
# What if you want to sort by two columns in the same way (ascending/descending)?
nba.sort_values(by = ["Team", "Name"], ascending = False).head()
# Out:
#                 Name                Team  Number Position   Age Height  \
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
#
#      Weight     College      Salary
# 379   190.0      Nevada   2170465.0
# 378   198.0  Georgetown   4662960.0
# 375   250.0         NaN  13000000.0
# 376   245.0      Kansas   8000000.0
# 381   205.0         LSU    200600.0

# %%
# But what if you want to sort by multiple columns but each column
# sort is unique (i.e., not both by ascending or descending)?
# Can provide ascending= a boolean list [True, False, True]
nba.sort_values(by = ["Team", "Name"], ascending = [True, False], inplace = True)
nba.head()
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
# 320   Thabo Sefolosha  Atlanta Hawks    25.0       SF  32.0    6-7   220.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
#
#             College      Salary
# 322             NaN   1000000.0
# 310        Michigan   1304520.0
# 321             NaN   9756250.0
# 320             NaN   4000000.0
# 315  Louisiana Tech  18671659.0

# %% [markdown]
# ## Sort DataFrame with .sort_index() Method
# Can help return data to original order/structure

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Let's mess up index order. You'll see index is 68, 1, 457
nba.sort_values(["Number", "Salary", "Name"], inplace = True)
nba.tail(3)
# Out:
#                Name             Team  Number Position   Age Height  Weight  \
# 68   Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN              NaN     NaN      NaN   NaN    NaN     NaN
#
#        College     Salary
# 68         NaN  1842000.0
# 1    Marquette  6796117.0
# 457        NaN        NaN

# %%
# Can return to original order by using .sort_index()
nba.sort_index(ascending = False, inplace = True)
nba.head()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0
# 454   900000.0
# 453  2433333.0

# %%
nba.shape
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.sort_index(axis = 1, ascending = True).head()
# Out:
#       Age College Height          Name  Number Position     Salary       Team  \
# 457   NaN     NaN    NaN           NaN     NaN      NaN        NaN        NaN
# 456  26.0  Kansas    7-0   Jeff Withey    24.0        C   947276.0  Utah Jazz
# 455  26.0     NaN    7-3  Tibor Pleiss    21.0        C  2900000.0  Utah Jazz
# 454  24.0     NaN    6-1     Raul Neto    25.0       PG   900000.0  Utah Jazz
# 453  26.0  Butler    6-3  Shelvin Mack     8.0       PG  2433333.0  Utah Jazz
#
#      Weight
# 457     NaN
# 456   231.0
# 455   256.0
# 454   179.0
# 453   203.0

# %%
nba.sort_index(axis = 0, ascending = True).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.columns = ["Name", "Position", "Number", "Team", "Age", "Height",
              "Weight", "Salary", "College"]
nba.head()
# Out:
#              Name   Position  Number Team   Age Height  Weight  Salary  \
# 457           NaN        NaN     NaN  NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0    C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0    C  26.0    7-3   256.0     NaN
# 454     Raul Neto  Utah Jazz    25.0   PG  24.0    6-1   179.0     NaN
# 453  Shelvin Mack  Utah Jazz     8.0   PG  26.0    6-3   203.0  Butler
#
#        College
# 457        NaN
# 456   947276.0
# 455  2900000.0
# 454   900000.0
# 453  2433333.0

# %%
nba.sort_index()
nba.columns[3:]
# Out:
# Index(['Team', 'Age', 'Height', 'Weight', 'Salary', 'College'], dtype='object')

# %% [markdown]
# ## Rank values with the .rank() Method
# *Note: Gotta clear all null values first. .rank is called on a single SERIES. By default .rank(ascending=True) will rank in reverse order (e.g., the lowest salary will rank #1

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#Delete nulls.
nba = pd.read_csv("nba.csv").dropna(how = 'all')
#Can't use inplace with .fillna() this time because after .fillna()
#the values (0) will still be FLOATS, so still have to call the
# .astype(dtype = 'int') to convert to INTEGER and THEN we can finally 
# use the .rank()
nba["Salary"] = nba["Salary"].fillna(value = 0).astype(dtype = "int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
# Let's rank the highest salaries. However, just .rank() gives us
# a couple of problems. 1. it's ranking in reverse order (note that
# index[2] was 0 for salary), so it's now ranked 6th. Need to change
# ascending param. 2. It ranks with FLOATS, but need to change dtype
# to "int".
nba["Salary"].rank()
nba["Salary"].rank(ascending = False)
nba["Salary"].rank(ascending = False).astype(dtype = "int").head()
# Out:
# 0     97
# 1    110
# 2    452
# 3    322
# 4    147
# Name: Salary, dtype: int64

# %%
# Can now assign to new series
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype(dtype = "int")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452
# 3      Georgia State  1148640          322
# 4                NaN  5000000          147

# %%
# Let's sort by Salaries
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 265              Marc Gasol       Memphis Grizzlies    33.0        C  31.0
# 96            Blake Griffin    Los Angeles Clippers    32.0       PF  27.0
# 315            Paul Millsap           Atlanta Hawks     4.0       PF  31.0
# 199             Paul George          Indiana Pacers    13.0       SF  26.0
# 426       Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# 233         Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 301           Kawhi Leonard       San Antonio Spurs     2.0       SF  24.0
# 418             Enes Kanter   Oklahoma City Thunder    11.0        C  24.0
# 153            Jimmy Butler           Chicago Bulls    21.0       SG  26.0
# 220             Greg Monroe         Milwaukee Bucks    15.0        C  26.0
# 189           Tobias Harris         Detroit Pistons    34.0       SF  23.0
# 382               John Wall      Washington Wizards     2.0       PG  25.0
# 143        DeMarcus Cousins        Sacramento Kings    15.0        C  25.0
# 249            James Harden         Houston Rockets    13.0       SG  26.0
# 111             Roy Hibbert      Los Angeles Lakers    17.0        C  29.0
# 288             Eric Gordon    New Orleans Pelicans    10.0       SG  27.0
# ..                      ...                     ...     ...      ...   ...
# 304            Andre Miller       San Antonio Spurs    24.0       PG  40.0
# 73           Jason Thompson         Toronto Raptors     1.0       PF  29.0
# 420           Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0
# 203               Ty Lawson          Indiana Pacers    10.0       PG  28.0
# 123          Chase Budinger            Phoenix Suns    10.0       SF  28.0
# 248        Andrew Goudelock         Houston Rockets     0.0       PG  27.0
# 381         Marcus Thornton      Washington Wizards    15.0       SF  29.0
# 303            Kevin Martin       San Antonio Spurs    23.0       SG  33.0
# 326         Jorge Gutierrez       Charlotte Hornets    12.0       PG  27.0
# 282      Bryce Dejean-Jones    New Orleans Pelicans    31.0       SG  23.0
# 45              Tony Wroten         New York Knicks     5.0       SG  23.0
# 21          Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 92               Jeff Ayres    Los Angeles Clippers    19.0       PF  29.0
# 184           Lorenzo Brown         Detroit Pistons    17.0       PG  25.0
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams            Phoenix Suns    15.0        C  23.0
# 130            Phil Pressey            Phoenix Suns    25.0       PG  25.0
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
#
#     Height  Weight                College    Salary  Salary Rank
# 109    6-6   212.0                    NaN  25000000            1
# 169    6-8   250.0                    NaN  22970500            2
# 33     6-8   240.0               Syracuse  22875000            3
# 251   6-11   265.0                    NaN  22359364            4
# 339   6-11   235.0           Georgia Tech  22192730            5
# 100    6-0   175.0            Wake Forest  21468695            6
# 414    6-9   240.0                  Texas  20158622            7
# 164    6-3   190.0                Memphis  20093064            8
# 349    6-4   220.0              Marquette  20000000            9
# 174   6-10   251.0                   UCLA  19689000           11
# 98    6-11   265.0              Texas A&M  19689000           11
# 23     7-0   275.0               Stanford  19689000           11
# 294   6-11   240.0                  Texas  19689000           11
# 265    7-1   255.0                    NaN  19688000           14
# 96    6-10   251.0               Oklahoma  18907726           15
# 315    6-8   246.0         Louisiana Tech  18671659           16
# 199    6-9   220.0           Fresno State  17120106           17
# 426    6-3   200.0                   UCLA  16744218           18
# 168    6-3   193.0                   Duke  16407501           19
# 233    6-5   220.0              Marquette  16407500           22
# 301    6-7   230.0        San Diego State  16407500           22
# 418   6-11   245.0               Kentucky  16407500           22
# 153    6-7   220.0              Marquette  16407500           22
# 220   6-11   265.0             Georgetown  16407500           22
# 189    6-9   235.0              Tennessee  16000000           25
# 382    6-4   195.0               Kentucky  15851950           26
# 143   6-11   270.0               Kentucky  15851950           26
# 249    6-5   220.0          Arizona State  15756438           28
# 111    7-2   270.0             Georgetown  15592217           29
# 288    6-4   215.0                Indiana  15514031           30
# ..     ...     ...                    ...       ...          ...
# 304    6-3   200.0                   Utah    250750          428
# 73    6-11   250.0                  Rider    245177          429
# 420   6-10   250.0               Kentucky    222888          430
# 203   5-11   195.0         North Carolina    211744          431
# 123    6-7   209.0                Arizona    206192          432
# 248    6-3   200.0             Charleston    200600          434
# 381    6-4   205.0                    LSU    200600          434
# 303    6-7   199.0       Western Carolina    200600          434
# 326    6-3   189.0             California    189455          436
# 282    6-6   203.0             Iowa State    169883          437
# 45     6-6   205.0             Washington    167406          438
# 21     6-4   219.0             Cincinnati    134215          439
# 92     6-9   250.0          Arizona State    111444          440
# 184    6-5   189.0   North Carolina State    111444          440
# 175    6-5   179.0              Tennessee    111196          442
# 135    6-8   260.0       UC Santa Barbara     83397          443
# 130   5-11   175.0               Missouri     55722          444
# 291    6-5   220.0       UC Santa Barbara     55722          444
# 32     6-7   205.0                    NaN     30888          446
# 350    6-2   165.0  Virginia Commonwealth         0          452
# 46     6-9   254.0                   Duke         0          452
# 2      6-5   205.0      Boston University         0          452
# 171    6-6   225.0                   Duke         0          452
# 397    6-7   210.0                    NaN         0          452
# 269    6-3   190.0                Detroit         0          452
# 353    6-9   205.0                    NaN         0          452
# 264    6-2   180.0                   UCLA         0          452
# 409   6-10   250.0           Fresno State         0          452
# 273   6-10   270.0                    USC         0          452
# 270    6-3   180.0           Rhode Island         0          452
#
# [457 rows x 10 columns]
